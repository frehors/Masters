# %%
from models.create_dataset import create_dataset
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import logging
import os
import json
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import hyperopt
import pickle

# %%
logging.basicConfig(level=logging.WARNING, format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
                    , handlers=[logging.FileHandler('DNN.log'), logging.StreamHandler()])
logger = logging.getLogger(__name__)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# create dataset
target_col = 'DK1_price'
df = create_dataset(target_col)
# Out:
# ['NO_Solar', 'NO_Solar_lag_1', 'NO_Solar_lag_2', 'NO_Solar_lag_3', 'NO_Solar_lag_7']

# %%
y = df[target_col]
X = df.drop(target_col, axis=1)

# %%
# Pivot hourly index out to columns so index is only date
pivot_columns = [col for col in X.columns if not col.startswith('day_of_week')]
X = X.pivot_table(index=X.index.date, columns=X.index.hour, values=pivot_columns)
X.columns = [f'hour_{col}' for col in X.columns]
X = X.dropna()
# Some hours will only have 0 values, drop these columns (e.g. Solar)
X = X.loc[:, (X != 0).any(axis=0)]
# and some are 0 almost always, drop features with a MAD below threshold
X = X.loc[:, X.sub(X.median(axis=0), axis=1).abs().median(axis=0) > 0.01]

# %%
# save median and mad for inverse transform
#X_median = X.median(axis=0)
#X_mad = X.mad(axis=0)

# %%
#X.sub(median, axis=1)
#X.div(mad, axis=1)

# %%
#

# %%
# Invariant asinh transform of data
# first Subtract median and then divide by median absolute deviation
class Scaler():

    def __init__(self, median=None, mad=None):
        self.median = None
        self.mad = None

    def fit(self, data):
        if isinstance(data, pd.Series):
            data = pd.DataFrame(data)
        self.median = data.median(axis=0).to_numpy()
        # calculate median absolute deviation
        self.mad = data.sub(data.median(axis=0), axis=1).abs().median(axis=0).to_numpy()
        # print na in mad
        return self

    def transform(self, data):
        if self.median is None or self.mad is None:
            raise ValueError('Fit scaler first')

        if isinstance(data, pd.Series):
            data = pd.DataFrame(data)
        X_transformed = data.sub(self.median, axis=1)
        X_transformed = X_transformed.div(self.mad, axis=1)
        X_transformed = np.arcsinh(X_transformed)

        return X_transformed

    def inverse_transform(self, data):

        if self.median is None or self.mad is None:
            raise ValueError('Fit scaler first')
        # fix so this works for series and dataframe
        if isinstance(data, pd.Series):
            data = pd.DataFrame(data)

        X_inversed = np.sinh(data)
        X_inversed = X_inversed.mul(self.mad, axis=1)
        X_inversed = X_inversed.add(self.median, axis=1)
        # make this work for series


        return X_inversed

# %%
#X = transform(X)
X.index = pd.to_datetime(X.index)
X['day_of_week'] = X.index.dayofweek

# to dummies
# day_of_week_0 column when day_of_week is 0, i.e. monday. 1 if monday, 0 otherwise
X['day_of_week_0'] = X['day_of_week'].apply(lambda x: 1 if x == 0 else 0)
X = pd.get_dummies(X, columns=['day_of_week'], drop_first=True) # last one should not be there, but we still use it?

# Drop Nan rows ( should be only first because im running UTC and thus the first "day" doesn't have 24 hrs)
X.isna().sum().sum()
# Out:
# 0

# %%
# now y
# make y to dataframe first, should alreadt be, but just to be sure
y = pd.DataFrame(y)
y = y.pivot_table(index=y.index.date, columns=y.index.hour, values=y.columns)
# join multiindex columns to one, price with hour number
y.index = pd.to_datetime(y.index)

y = y.dropna()

# %%
##### temporary start cut off as well to see if it works
#start_cutoff = pd.to_datetime('2019-01-01 00:00')
val_cutoff = pd.to_datetime('2020-07-01')
test_cutoff = pd.to_datetime('2021-01-01')
#X_train = X.loc[X.index >= start_cutoff & X.index < val_cutoff]
X_train = X.loc[X.index < val_cutoff]
X_val = X.loc[(X.index >= val_cutoff) & (X.index < test_cutoff)]
X_test = X.loc[X.index >= test_cutoff]
#y_train = y.loc[y.index < val_cutoff & y.index >= start_cutoff]
y_train = y.loc[y.index < val_cutoff]
y_val = y.loc[(y.index >= val_cutoff) & (y.index < test_cutoff)]
y_test = y.loc[y.index >= test_cutoff]
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
#X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, shuffle=False)

# %%
class DNN4(nn.Module):
    def __init__(self, input_dim, output_dim, num_neurons, dropout_rate):
        # assure lenght of num_neurons is 3
        assert len(num_neurons) == 3

        super(DNN4, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.fc1 = nn.Linear(self.input_dim, num_neurons[0])
        self.fc2 = nn.Linear(num_neurons[0], num_neurons[1])
        self.fc3 = nn.Linear(num_neurons[1], num_neurons[2])
        self.fc4 = nn.Linear(num_neurons[2], self.output_dim)
        self.dropout = nn.Dropout(dropout_rate)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.relu(self.fc3(x))
        x = self.dropout(x)
        x = self.fc4(x)
        return x

# %%
# make dataloader
# and small test to see if it works, it does :)
# train_loader = DataLoader(dataset=list(zip(X_train.values, y_train.values)), batch_size=32, shuffle=False)
# val_loader = DataLoader(dataset=list(zip(X_val.values, y_val.values)), batch_size=32, shuffle=False)
#X.head()

# %%
# Tree structured parzen estimator

optimize_hyperparameters = False

if optimize_hyperparameters:
    from hyperopt import fmin, tpe, hp, Trials

    epochs = 50
    criterion = nn.MSELoss() # maybe not this one, but for now

    # Define the search space
    space = {
        'weight_decay': hp.loguniform('weight_decay', -10, -1),
        'batch_size': hp.choice('batch_size', [16, 32, 64, 128, 256]),
        'learning_rate': hp.loguniform('learning_rate', -8, -1),
        'num_neurons_1': hp.quniform('num_neurons_1', 32, 512, 32),
        'num_neurons_2': hp.quniform('num_neurons_2', 32, 512, 32),
        'num_neurons_3': hp.quniform('num_neurons_3', 32, 512, 32),
        'dropout_rate': hp.uniform('dropout_rate', 0, 0.5)
    }

    # Define the objective function
    def objective(params, input_dim=X_train.shape[1], output_dim=24):
        # Train and evaluate your model with the given hyperparameters
        # Return the validation accuracy or other metric you want to optimize
        params['num_neurons_1'] = int(params['num_neurons_1'])
        params['num_neurons_2'] = int(params['num_neurons_2'])
        params['num_neurons_3'] = int(params['num_neurons_3'])
        model = DNN4(input_dim, output_dim, [params['num_neurons_1'], params['num_neurons_2'], params['num_neurons_3']], params['dropout_rate']).to(device)
        optimizer = optim.Adam(model.parameters(), lr=params['learning_rate'], weight_decay=params['weight_decay'])
        # print layers
        # __loader__
        # fit scaler first, then transform: Fitting on training data then transforming on training and validation data

        XScaler = Scaler()
        # fit scaler without last 7 features
        XScaler.fit(X_train.iloc[:, :-7])


        X_train_scaled = XScaler.transform(X_train.iloc[:, :-7])
        # add dummies
        X_train_scaled = pd.concat([X_train_scaled, X_train.iloc[:, -7:]], axis=1)
        X_val_scaled = XScaler.transform(X_val.iloc[:, :-7])
        X_val_scaled = pd.concat([X_val_scaled, X_val.iloc[:, -7:]], axis=1)

        yScaler = Scaler()
        yScaler.fit(y_train)
        y_train_scaled = yScaler.transform(y_train)
        y_val_scaled = yScaler.transform(y_val)
        #train_dataset = Dataset()
        #train_dataset.load_data(X_train_scaled, y_train_scaled)
        train_loader = DataLoader(dataset=list(zip(X_train_scaled.values, y_train_scaled.values)), batch_size=params['batch_size'], shuffle=False)


        val_loader = DataLoader(dataset=list(zip(X_val_scaled.values, y_val_scaled.values)), batch_size=params['batch_size'], shuffle=False)
        train_losses = []
        val_losses = []
        best_val_loss = np.inf
        for epoch in range(epochs):
            train_loss = 0.0
            val_loss = 0.0
            model.train()
            for i, (inputs, labels) in enumerate(train_loader):
                # transfer to GPU
                inputs, labels = inputs.float().to(device), labels.float().to(device)


                # zero the parameter gradients
                optimizer.zero_grad()
                # forward + backward + optimize
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                # print statistics
                train_loss += loss.item()

            model.eval()
            for i, (inputs, labels) in enumerate(val_loader):
                # transfer to GPU

                inputs, labels = inputs.float().to(device), labels.float().to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

            train_losses.append(train_loss/len(train_loader))
            val_losses.append(val_loss/len(val_loader))
            # early stopping
            if epoch % 5 == 0:

                # if val hasn't decreased for 5 epochs, stop
                if min(val_losses[-3:]) > best_val_loss:
                    break
                best_val_loss = min(val_losses[-3:])

        #accuracy = val_losses[-1]
        # min of last 3 val losses
        accuracy = min(val_losses[-3:])

        return accuracy

    # Define the TPE algorithm
    tpe_algorithm = tpe.suggest

    # Define the number of iterations
    max_evals = 1500

    # Initialize the trials object
    trials = Trials()

    # Run the TPE algorithm to optimize the hyperparameters
    best_params = fmin(objective, space, algo=tpe_algorithm, max_evals=max_evals, trials=trials, verbose=True)

    # Print the best hyperparameters
    print("Best hyperparameters:", best_params)
    # save best parameters to json
    param_path = r'C:\Users\frede\PycharmProjects\Masters\models\DNN\best_params.pkl'
    pickle.dump(best_params, open(param_path, 'wb'))
    trials_path = r'C:\Users\frede\PycharmProjects\Masters\models\DNN\trials.pkl'
    pickle.dump(trials, open(trials_path, 'wb'))

# %%
# load best hyper parameters
param_path = os.path.join('.', 'best_params.pkl')
best_params = pickle.load(open(param_path, 'rb'))

# get another param to see if it works
logger.info(f'Training model, with best hyperparameters {best_params}')

# %%
def build_train_model(model, date_to_forecast, X_training, y_training, X_validation, y_validation, batch_size, epochs, device_name='cpu'):
    # setup model


    best_val_loss = np.inf
    train_losses = []
    val_losses = []

    train_loader = DataLoader(dataset=list(zip(X_training.values, y_training.values)), batch_size=batch_size, shuffle=False)
    val_loader = DataLoader(dataset=list(zip(X_validation.values, y_validation.values)), batch_size=batch_size, shuffle=False)

    model.train()
    for epoch in range(epochs):
        train_loss = 0.0
        val_loss = 0.0
        for i, (inputs, labels) in enumerate(train_loader):
            # transfer to GPU
            inputs, labels = inputs.float().to(device_name), labels.float().to(device_name)
            assert not torch.isnan(inputs).any()
            assert not torch.isnan(labels).any()

            # zero the parameter gradients
            optimizer.zero_grad()
            # forward + backward + optimize
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            # print statistics
            train_loss += loss.item()



        model.eval()
        for i, (inputs, labels) in enumerate(val_loader):
            # transfer to GPU
            inputs, labels = inputs.float().to(device_name), labels.float().to(device_name)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

        train_losses.append(train_loss/len(train_loader))
        val_losses.append(val_loss/len(val_loader))
        # early stopping, every 5th epoch check if val loss has decreased
        if epoch % 5 == 0:

            # if val hasn't decreased for 5 epochs, stop
            if val_losses[-1] > best_val_loss:
                print(f'Terminated epoch {epoch + 1}/{epochs} early: train loss: {round(train_losses[-1], 2)}, val loss: {round(val_losses[-1], 2)}')
                break
            best_val_loss = val_losses[-1]

        logger.info(f'Epoch {epoch + 1}/{epochs} complete, train loss: {train_losses[-1]}, val loss: {val_losses[-1]}')

    #accuracy = val_losses[-1]
    # min of last 3 val losses
    # save model
    model_path = os.path.join(os.getcwd(), 'models', f'{date_to_forecast.strftime("%Y-%m-%d")}_DNN4_model.pth')
    torch.save(model.state_dict(), model_path)

    # save train and val losses
    losses_path = os.path.join(os.getcwd(), 'losses', f'{date_to_forecast.strftime("%Y-%m-%d")}_DNN4_losses.pkl')
    pickle.dump([train_losses, val_losses], open(losses_path, 'wb'))

    return model, train_losses, val_losses


# we want to go throught each day, train on all previous data except 1 week, then predict 1 day, then move on to next day
# we want to save the predictions for each day, and then evaluate the model on the whole dataset

# %%
# setup model
input_dim = X_train.shape[1]
output_dim = 24

best_params['num_neurons_1'] = int(best_params['num_neurons_1'])
best_params['num_neurons_2'] = int(best_params['num_neurons_2'])
best_params['num_neurons_3'] = int(best_params['num_neurons_3'])
best_params['batch_size'] = int(best_params['batch_size'])

model = DNN4(input_dim,
             output_dim,
             [best_params['num_neurons_1'], best_params['num_neurons_2'], best_params['num_neurons_3']],
             best_params['dropout_rate']).to(device)

optimizer = optim.Adam(model.parameters(), lr=best_params['learning_rate'], weight_decay=best_params['weight_decay'])
# loss
criterion = nn.MSELoss()

# %%
# first we train model on all data except last week before testing, then recalibrate afterwards only on last year
XScaler = Scaler()
XScaler.fit(X_train.iloc[:, :-7])

X_train_scaled = XScaler.transform(X_train.iloc[:, :-7])
# add dummies
X_train_scaled = pd.concat([X_train_scaled, X_train.iloc[:, -7:]], axis=1)
X_val_scaled = XScaler.transform(X_val.iloc[:, :-7])
X_val_scaled = pd.concat([X_val_scaled, X_val.iloc[:, -7:]], axis=1)

yScaler = Scaler()
yScaler.fit(y_train)
y_train_scaled = yScaler.transform(y_train)
y_val_scaled = yScaler.transform(y_val)

model, _, _ = build_train_model(model=model, date_to_forecast=test_cutoff, X_training=X_train_scaled, y_training=y_train_scaled, X_validation=X_val_scaled, y_validation=y_val_scaled, batch_size=best_params['batch_size'], epochs=epochs, device_name=device)
# Out:
# Terminated epoch 11/50 early: train loss: 0.18, val loss: 0.62

# %%
predictions_path = os.path.join(os.getcwd(), 'predictions', f'DNN4_predictions.pkl')
predictions = []

epochs = 50


for i, date in enumerate(X_test.index):
    X_train_date = X[(X.index < date - pd.Timedelta(days=7)) & (X.index > date - pd.Timedelta(days=365))]
    y_train_date = y[(y.index < date - pd.Timedelta(days=7)) & (X.index > date - pd.Timedelta(days=365))]
    X_val_date = X[(X.index >= date - pd.Timedelta(days=7)) & (X.index < date)]
    y_val_date = y[(y.index >= date - pd.Timedelta(days=7)) & (y.index < date)]
    X_test_date = X[X.index == date]
    y_test_date = y[y.index == date]
    # Transform data
    XScaler = Scaler()
    XScaler.fit(X_train_date.iloc[:, :-7])
    X_train_date_transformed = XScaler.transform(X_train_date.iloc[:, :-7])
    # add dummies
    X_train_date_transformed = pd.concat([X_train_date_transformed, X_train_date.iloc[:, -7:]], axis=1)

    X_val_date_transformed = XScaler.transform(X_val_date.iloc[:, :-7])
    X_val_date_transformed = pd.concat([X_val_date_transformed, X_val_date.iloc[:, -7:]], axis=1)
    X_test_date_transformed = XScaler.transform(X_test_date.iloc[:, :-7])
    X_test_date_transformed = pd.concat([X_test_date_transformed, X_test_date.iloc[:, -7:]], axis=1)

    # Make test pandas dataframe into tensor
    X_test_date = torch.tensor(X_test_date.values).float().to(device)
    yScaler = Scaler()
    yScaler.fit(y_train_date)
    y_train_date = yScaler.transform(y_train_date)
    y_val_date = yScaler.transform(y_val_date)
    y_test_date = yScaler.transform(y_test_date)
    # train model
    model.train()
    model, train_losses, val_losses = build_train_model(model=model,
                                                        date_to_forecast=date,
                                                        X_training=X_train_date_transformed,
                                                        y_training=y_train_date,
                                                        X_validation=X_val_date_transformed,
                                                        y_validation=y_val_date,
                                                        batch_size=best_params['batch_size'],
                                                        epochs=epochs,
                                                        device_name=device)


    # predict and detach to cpu and make into pandas series
    X_test_date_transformed = torch.tensor(X_test_date_transformed.values).float().to(device)
    # disable dropout
    model = model.eval()
    y_pred = model(X_test_date_transformed).detach().cpu().numpy()
    y_pred = pd.DataFrame(y_pred, index=y_test_date.index)
    y_pred = yScaler.inverse_transform(y_pred)
    y_true = yScaler.inverse_transform(y_test_date)

    predictions.append(y_pred)

    logger.info(f'Training model for date {date} ({i+1}/{len(X_test.index)}): MAE: {mean_absolute_error(y_true, y_pred)}')
    print(date, 'MAE:', round(mean_absolute_error(y_true, y_pred), 2))
    print('predicted mean', round(y_pred.mean().mean(), 2))
    print('true mean', round(y_true.mean().mean(), 2))

    # every quarter, save model and losses and predictions
    if date.month % 3 == 0 and date.day == 1:


        # save predictions
        predictions_path = os.path.join(os.getcwd(), 'predictions', f'{date.strftime("%Y-%m-%d")}_DNN4_predictions.pkl')
        pickle.dump(pd.concat(predictions, axis=0), open(predictions_path, 'wb'))
# Out:
# Terminated epoch 11/50 early: train loss: 0.13, val loss: 0.79
# 2021-01-01 00:00:00 MAE: 17.93
# predicted mean 30.3
# true mean 48.22
# Terminated epoch 11/50 early: train loss: 0.08, val loss: 0.35
# 2021-01-02 00:00:00 MAE: 3.58
# predicted mean 49.1
# true mean 50.54
# Terminated epoch 11/50 early: train loss: 0.08, val loss: 0.38
# 2021-01-03 00:00:00 MAE: 7.53
# predicted mean 31.84
# true mean 27.55
# Terminated epoch 6/50 early: train loss: 0.07, val loss: 0.47
# 2021-01-04 00:00:00 MAE: 12.16
# predicted mean 30.28
# true mean 42.3
# Terminated epoch 6/50 early: train loss: 0.06, val loss: 0.34
# 2021-01-05 00:00:00 MAE: 15.82
# predicted mean 31.54
# true mean 47.36
# Terminated epoch 11/50 early: train loss: 0.07, val loss: 0.4
# 2021-01-06 00:00:00 MAE: 10.67
# predicted mean 30.95
# true mean 41.61
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.53
# 2021-01-07 00:00:00 MAE: 27.12
# predicted mean 40.82
# true mean 67.95
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.33
# 2021-01-08 00:00:00 MAE: 30.78
# predicted mean 46.16
# true mean 76.94
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.48
# 2021-01-09 00:00:00 MAE: 15.94
# predicted mean 41.84
# true mean 57.78
# Terminated epoch 16/50 early: train loss: 0.06, val loss: 0.68
# 2021-01-10 00:00:00 MAE: 10.54
# predicted mean 33.07
# true mean 43.61
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.34
# 2021-01-11 00:00:00 MAE: 9.47
# predicted mean 31.42
# true mean 40.69
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.49
# 2021-01-12 00:00:00 MAE: 23.12
# predicted mean 21.41
# true mean 44.46
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.81
# 2021-01-13 00:00:00 MAE: 20.1
# predicted mean 22.17
# true mean 42.28
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.28
# 2021-01-14 00:00:00 MAE: 10.53
# predicted mean 70.55
# true mean 70.9
# Terminated epoch 6/50 early: train loss: 0.05, val loss: 0.54
# 2021-01-15 00:00:00 MAE: 12.6
# predicted mean 65.69
# true mean 73.06
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.32
# 2021-01-16 00:00:00 MAE: 7.33
# predicted mean 58.06
# true mean 54.77
# Terminated epoch 6/50 early: train loss: 0.05, val loss: 0.71
# 2021-01-17 00:00:00 MAE: 4.67
# predicted mean 54.54
# true mean 52.89
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.98
# 2021-01-18 00:00:00 MAE: 11.92
# predicted mean 42.48
# true mean 54.4
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.21
# 2021-01-19 00:00:00 MAE: 2.79
# predicted mean 47.01
# true mean 44.94
# Terminated epoch 6/50 early: train loss: 0.05, val loss: 0.39
# 2021-01-20 00:00:00 MAE: 3.0
# predicted mean 32.58
# true mean 34.72
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.43
# 2021-01-21 00:00:00 MAE: 15.57
# predicted mean 40.09
# true mean 27.48
# Terminated epoch 11/50 early: train loss: 0.07, val loss: 0.25
# 2021-01-22 00:00:00 MAE: 10.5
# predicted mean 20.57
# true mean 31.07
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.21
# 2021-01-23 00:00:00 MAE: 10.14
# predicted mean 49.69
# true mean 49.31
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.21
# 2021-01-24 00:00:00 MAE: 28.88
# predicted mean 78.12
# true mean 49.24
# Terminated epoch 6/50 early: train loss: 0.05, val loss: 0.26
# 2021-01-25 00:00:00 MAE: 3.82
# predicted mean 60.46
# true mean 60.67
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.32
# 2021-01-26 00:00:00 MAE: 4.36
# predicted mean 61.52
# true mean 60.89
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.22
# 2021-01-27 00:00:00 MAE: 5.47
# predicted mean 63.33
# true mean 57.86
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.51
# 2021-01-28 00:00:00 MAE: 8.27
# predicted mean 64.08
# true mean 55.81
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.15
# 2021-01-29 00:00:00 MAE: 2.46
# predicted mean 49.1
# true mean 49.78
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.15
# 2021-01-30 00:00:00 MAE: 1.98
# predicted mean 48.35
# true mean 48.67
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.26
# 2021-01-31 00:00:00 MAE: 27.14
# predicted mean 75.34
# true mean 48.2
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.11
# 2021-02-01 00:00:00 MAE: 29.17
# predicted mean 86.89
# true mean 57.72
# Terminated epoch 16/50 early: train loss: 0.06, val loss: 0.08
# 2021-02-02 00:00:00 MAE: 9.74
# predicted mean 62.45
# true mean 54.19
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.05
# 2021-02-03 00:00:00 MAE: 9.07
# predicted mean 35.38
# true mean 44.46
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.14
# 2021-02-04 00:00:00 MAE: 2.95
# predicted mean 54.89
# true mean 52.53
# Terminated epoch 6/50 early: train loss: 0.06, val loss: 0.12
# 2021-02-05 00:00:00 MAE: 11.23
# predicted mean 48.43
# true mean 51.18
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.17
# 2021-02-06 00:00:00 MAE: 6.19
# predicted mean 33.01
# true mean 34.69
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.22
# 2021-02-07 00:00:00 MAE: 13.77
# predicted mean 30.94
# true mean 20.03
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.42
# 2021-02-08 00:00:00 MAE: 9.43
# predicted mean 50.27
# true mean 44.72
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.57
# 2021-02-09 00:00:00 MAE: 17.24
# predicted mean 46.88
# true mean 64.12
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.59
# 2021-02-10 00:00:00 MAE: 21.23
# predicted mean 51.1
# true mean 72.33
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.59
# 2021-02-11 00:00:00 MAE: 15.13
# predicted mean 64.14
# true mean 79.11
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.65
# 2021-02-12 00:00:00 MAE: 7.18
# predicted mean 59.78
# true mean 62.34
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.53
# 2021-02-13 00:00:00 MAE: 3.16
# predicted mean 53.33
# true mean 53.12
# Terminated epoch 6/50 early: train loss: 0.06, val loss: 0.47
# 2021-02-14 00:00:00 MAE: 6.93
# predicted mean 51.85
# true mean 45.59
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.26
# 2021-02-15 00:00:00 MAE: 8.88
# predicted mean 41.98
# true mean 50.73
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.19
# 2021-02-16 00:00:00 MAE: 23.53
# predicted mean 75.63
# true mean 52.1
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.27
# 2021-02-17 00:00:00 MAE: 8.0
# predicted mean 42.32
# true mean 49.68
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.39
# 2021-02-18 00:00:00 MAE: 11.28
# predicted mean 33.91
# true mean 45.18
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.11
# 2021-02-19 00:00:00 MAE: 9.58
# predicted mean 38.22
# true mean 47.8
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.22
# 2021-02-20 00:00:00 MAE: 9.31
# predicted mean 24.86
# true mean 33.2
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.31
# 2021-02-21 00:00:00 MAE: 9.11
# predicted mean 24.94
# true mean 33.79
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.36
# 2021-02-22 00:00:00 MAE: 9.72
# predicted mean 40.47
# true mean 49.32
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.5
# 2021-02-23 00:00:00 MAE: 7.41
# predicted mean 38.09
# true mean 43.81
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.2
# 2021-02-24 00:00:00 MAE: 2.49
# predicted mean 32.16
# true mean 31.53
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.38
# 2021-02-25 00:00:00 MAE: 5.65
# predicted mean 37.12
# true mean 33.21
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.21
# 2021-02-26 00:00:00 MAE: 5.55
# predicted mean 33.89
# true mean 31.01
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.26
# 2021-02-27 00:00:00 MAE: 4.69
# predicted mean 45.64
# true mean 44.57
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.18
# 2021-02-28 00:00:00 MAE: 6.35
# predicted mean 36.38
# true mean 41.33
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.17
# 2021-03-01 00:00:00 MAE: 6.57
# predicted mean 45.69
# true mean 49.25
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.17
# 2021-03-02 00:00:00 MAE: 6.49
# predicted mean 52.98
# true mean 53.55
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.3
# 2021-03-03 00:00:00 MAE: 12.94
# predicted mean 64.66
# true mean 51.72
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.17
# 2021-03-04 00:00:00 MAE: 7.58
# predicted mean 45.88
# true mean 53.34
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.16
# 2021-03-05 00:00:00 MAE: 10.28
# predicted mean 43.42
# true mean 53.7
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.13
# 2021-03-06 00:00:00 MAE: 5.89
# predicted mean 30.69
# true mean 33.88
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.15
# 2021-03-07 00:00:00 MAE: 8.75
# predicted mean 32.14
# true mean 40.66
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.13
# 2021-03-08 00:00:00 MAE: 7.1
# predicted mean 55.61
# true mean 61.62
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.11
# 2021-03-09 00:00:00 MAE: 10.89
# predicted mean 71.08
# true mean 61.25
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.14
# 2021-03-10 00:00:00 MAE: 5.28
# predicted mean 45.71
# true mean 45.77
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.13
# 2021-03-11 00:00:00 MAE: 11.89
# predicted mean 19.07
# true mean 24.97
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.23
# 2021-03-12 00:00:00 MAE: 17.16
# predicted mean 13.27
# true mean 22.66
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.27
# 2021-03-13 00:00:00 MAE: 15.17
# predicted mean 30.74
# true mean 15.75
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.37
# 2021-03-14 00:00:00 MAE: 12.35
# predicted mean 26.99
# true mean 20.13
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.37
# 2021-03-15 00:00:00 MAE: 14.56
# predicted mean 33.93
# true mean 48.49
# Terminated epoch 6/50 early: train loss: 0.05, val loss: 0.44
# 2021-03-16 00:00:00 MAE: 6.5
# predicted mean 49.53
# true mean 55.94
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.38
# 2021-03-17 00:00:00 MAE: 5.91
# predicted mean 56.72
# true mean 57.85
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.43
# 2021-03-18 00:00:00 MAE: 9.05
# predicted mean 56.1
# true mean 65.15
# Terminated epoch 6/50 early: train loss: 0.05, val loss: 0.44
# 2021-03-19 00:00:00 MAE: 9.5
# predicted mean 46.86
# true mean 56.36
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.31
# 2021-03-20 00:00:00 MAE: 10.34
# predicted mean 33.91
# true mean 40.24
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.35
# 2021-03-21 00:00:00 MAE: 15.81
# predicted mean 17.44
# true mean 33.25
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.57
# 2021-03-22 00:00:00 MAE: 12.72
# predicted mean 45.65
# true mean 58.24
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.32
# 2021-03-23 00:00:00 MAE: 16.58
# predicted mean 43.23
# true mean 59.81
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.23
# 2021-03-24 00:00:00 MAE: 10.52
# predicted mean 42.63
# true mean 53.0
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.31
# 2021-03-25 00:00:00 MAE: 12.02
# predicted mean 44.6
# true mean 56.62
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.43
# 2021-03-26 00:00:00 MAE: 4.92
# predicted mean 39.82
# true mean 42.21
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.37
# 2021-03-27 00:00:00 MAE: 14.05
# predicted mean 21.07
# true mean 24.56
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.51
# 2021-03-28 00:00:00 MAE: 30.69
# predicted mean -8.44
# true mean 22.25
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.51
# 2021-03-29 00:00:00 MAE: 8.49
# predicted mean 27.4
# true mean 31.38
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.56
# 2021-03-30 00:00:00 MAE: 15.7
# predicted mean 55.95
# true mean 46.91
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.43
# 2021-03-31 00:00:00 MAE: 21.37
# predicted mean 75.74
# true mean 58.12
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.66
# 2021-04-01 00:00:00 MAE: 6.46
# predicted mean 44.69
# true mean 47.04
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.59
# 2021-04-02 00:00:00 MAE: 12.21
# predicted mean 41.51
# true mean 32.06
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.66
# 2021-04-03 00:00:00 MAE: 6.36
# predicted mean 38.99
# true mean 39.68
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.54
# 2021-04-04 00:00:00 MAE: 9.49
# predicted mean 11.52
# true mean 16.92
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.38
# 2021-04-05 00:00:00 MAE: 24.03
# predicted mean 14.5
# true mean -9.09
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.42
# 2021-04-06 00:00:00 MAE: 6.38
# predicted mean 28.44
# true mean 31.32
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.33
# 2021-04-07 00:00:00 MAE: 9.19
# predicted mean 42.51
# true mean 46.94
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.42
# 2021-04-08 00:00:00 MAE: 14.48
# predicted mean 34.0
# true mean 42.88
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.53
# 2021-04-09 00:00:00 MAE: 8.38
# predicted mean 21.66
# true mean 25.42
# Terminated epoch 11/50 early: train loss: 0.07, val loss: 0.55
# 2021-04-10 00:00:00 MAE: 17.84
# predicted mean 53.47
# true mean 54.19
# Terminated epoch 6/50 early: train loss: 0.05, val loss: 0.51
# 2021-04-11 00:00:00 MAE: 12.98
# predicted mean 34.86
# true mean 46.6
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.66
# 2021-04-12 00:00:00 MAE: 10.06
# predicted mean 35.72
# true mean 45.39
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.54
# 2021-04-13 00:00:00 MAE: 4.58
# predicted mean 47.95
# true mean 49.47
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.51
# 2021-04-14 00:00:00 MAE: 17.28
# predicted mean 82.4
# true mean 68.93
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.38
# 2021-04-15 00:00:00 MAE: 11.37
# predicted mean 58.9
# true mean 63.6
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.32
# 2021-04-16 00:00:00 MAE: 12.93
# predicted mean 52.36
# true mean 55.7
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.36
# 2021-04-17 00:00:00 MAE: 14.46
# predicted mean 44.79
# true mean 59.25
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.29
# 2021-04-18 00:00:00 MAE: 10.19
# predicted mean 50.73
# true mean 60.92
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.25
# 2021-04-19 00:00:00 MAE: 13.33
# predicted mean 70.32
# true mean 71.0
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.16
# 2021-04-20 00:00:00 MAE: 10.44
# predicted mean 80.08
# true mean 75.56
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.12
# 2021-04-21 00:00:00 MAE: 9.62
# predicted mean 49.36
# true mean 45.09
# Terminated epoch 11/50 early: train loss: 0.07, val loss: 0.22
# 2021-04-22 00:00:00 MAE: 11.87
# predicted mean 41.44
# true mean 34.03
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.27
# 2021-04-23 00:00:00 MAE: 8.74
# predicted mean 43.65
# true mean 48.36
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.31
# 2021-04-24 00:00:00 MAE: 5.66
# predicted mean 52.52
# true mean 48.78
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.24
# 2021-04-25 00:00:00 MAE: 19.93
# predicted mean 56.17
# true mean 37.66
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.4
# 2021-04-26 00:00:00 MAE: 27.41
# predicted mean 87.46
# true mean 61.65
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.43
# 2021-04-27 00:00:00 MAE: 25.01
# predicted mean 83.76
# true mean 58.82
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.52
# 2021-04-28 00:00:00 MAE: 24.42
# predicted mean 82.13
# true mean 59.83
# Terminated epoch 6/50 early: train loss: 0.05, val loss: 0.58
# 2021-04-29 00:00:00 MAE: 4.9
# predicted mean 56.29
# true mean 54.38
# Terminated epoch 6/50 early: train loss: 0.05, val loss: 0.81
# 2021-04-30 00:00:00 MAE: 8.22
# predicted mean 74.13
# true mean 68.26
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.34
# 2021-05-01 00:00:00 MAE: 9.0
# predicted mean 64.56
# true mean 55.6
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.38
# 2021-05-02 00:00:00 MAE: 9.81
# predicted mean 56.08
# true mean 46.91
# Terminated epoch 16/50 early: train loss: 0.06, val loss: 0.42
# 2021-05-03 00:00:00 MAE: 15.06
# predicted mean 75.93
# true mean 61.43
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.56
# 2021-05-04 00:00:00 MAE: 41.54
# predicted mean 70.28
# true mean 28.74
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.69
# 2021-05-05 00:00:00 MAE: 12.42
# predicted mean 43.45
# true mean 37.97
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.56
# 2021-05-06 00:00:00 MAE: 9.59
# predicted mean 61.13
# true mean 66.96
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.5
# 2021-05-07 00:00:00 MAE: 8.08
# predicted mean 61.91
# true mean 68.58
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.64
# 2021-05-08 00:00:00 MAE: 12.23
# predicted mean 54.74
# true mean 46.88
# Terminated epoch 6/50 early: train loss: 0.05, val loss: 0.58
# 2021-05-09 00:00:00 MAE: 31.74
# predicted mean 41.86
# true mean 10.12
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.84
# 2021-05-10 00:00:00 MAE: 10.35
# predicted mean 50.01
# true mean 57.98
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.85
# 2021-05-11 00:00:00 MAE: 7.29
# predicted mean 64.56
# true mean 71.57
# Terminated epoch 21/50 early: train loss: 0.05, val loss: 0.52
# 2021-05-12 00:00:00 MAE: 7.69
# predicted mean 69.9
# true mean 69.07
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.46
# 2021-05-13 00:00:00 MAE: 6.25
# predicted mean 62.44
# true mean 63.41
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.5
# 2021-05-14 00:00:00 MAE: 9.71
# predicted mean 64.88
# true mean 71.58
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.5
# 2021-05-15 00:00:00 MAE: 16.97
# predicted mean 41.63
# true mean 58.6
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.57
# 2021-05-16 00:00:00 MAE: 16.59
# predicted mean 43.85
# true mean 40.47
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.41
# 2021-05-17 00:00:00 MAE: 18.11
# predicted mean 56.28
# true mean 74.39
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.45
# 2021-05-18 00:00:00 MAE: 11.83
# predicted mean 62.68
# true mean 74.52
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.38
# 2021-05-19 00:00:00 MAE: 14.61
# predicted mean 65.72
# true mean 77.52
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.46
# 2021-05-20 00:00:00 MAE: 12.51
# predicted mean 48.09
# true mean 57.95
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.48
# 2021-05-21 00:00:00 MAE: 14.68
# predicted mean 27.35
# true mean 31.81
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.67
# 2021-05-22 00:00:00 MAE: 18.57
# predicted mean 13.21
# true mean 11.21
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.57
# 2021-05-23 00:00:00 MAE: 13.62
# predicted mean 15.13
# true mean 22.85
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.47
# 2021-05-24 00:00:00 MAE: 12.89
# predicted mean 49.78
# true mean 41.31
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.6
# 2021-05-25 00:00:00 MAE: 16.27
# predicted mean 43.98
# true mean 60.25
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.69
# 2021-05-26 00:00:00 MAE: 19.4
# predicted mean 46.41
# true mean 65.54
# Terminated epoch 16/50 early: train loss: 0.03, val loss: 0.74
# 2021-05-27 00:00:00 MAE: 6.31
# predicted mean 66.34
# true mean 72.44
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.78
# 2021-05-28 00:00:00 MAE: 11.21
# predicted mean 62.6
# true mean 73.81
# Terminated epoch 21/50 early: train loss: 0.04, val loss: 0.56
# 2021-05-29 00:00:00 MAE: 11.12
# predicted mean 51.07
# true mean 55.48
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.53
# 2021-05-30 00:00:00 MAE: 9.58
# predicted mean 35.63
# true mean 40.45
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.48
# 2021-05-31 00:00:00 MAE: 5.34
# predicted mean 64.49
# true mean 67.62
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.45
# 2021-06-01 00:00:00 MAE: 4.94
# predicted mean 69.49
# true mean 68.48
# Terminated epoch 16/50 early: train loss: 0.06, val loss: 0.31
# 2021-06-02 00:00:00 MAE: 12.63
# predicted mean 76.4
# true mean 64.23
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.18
# 2021-06-03 00:00:00 MAE: 10.64
# predicted mean 46.43
# true mean 55.94
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.2
# 2021-06-04 00:00:00 MAE: 3.61
# predicted mean 73.19
# true mean 71.94
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.19
# 2021-06-05 00:00:00 MAE: 6.52
# predicted mean 55.25
# true mean 61.59
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.14
# 2021-06-06 00:00:00 MAE: 10.24
# predicted mean 49.58
# true mean 59.82
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.11
# 2021-06-07 00:00:00 MAE: 14.95
# predicted mean 62.77
# true mean 77.73
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.14
# 2021-06-08 00:00:00 MAE: 13.78
# predicted mean 63.1
# true mean 76.88
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.08
# 2021-06-09 00:00:00 MAE: 9.51
# predicted mean 84.37
# true mean 77.43
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.13
# 2021-06-10 00:00:00 MAE: 9.47
# predicted mean 72.32
# true mean 79.06
# Terminated epoch 26/50 early: train loss: 0.04, val loss: 0.09
# 2021-06-11 00:00:00 MAE: 10.55
# predicted mean 67.44
# true mean 77.78
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.06
# 2021-06-12 00:00:00 MAE: 16.9
# predicted mean 42.89
# true mean 32.8
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.22
# 2021-06-13 00:00:00 MAE: 21.08
# predicted mean 32.0
# true mean 23.41
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.27
# 2021-06-14 00:00:00 MAE: 15.86
# predicted mean 59.21
# true mean 74.89
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.29
# 2021-06-15 00:00:00 MAE: 16.14
# predicted mean 67.4
# true mean 82.55
# Terminated epoch 21/50 early: train loss: 0.03, val loss: 0.35
# 2021-06-16 00:00:00 MAE: 12.85
# predicted mean 84.83
# true mean 84.33
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.48
# 2021-06-17 00:00:00 MAE: 20.79
# predicted mean 57.13
# true mean 77.92
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.36
# 2021-06-18 00:00:00 MAE: 14.73
# predicted mean 65.79
# true mean 80.53
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.74
# 2021-06-19 00:00:00 MAE: 9.11
# predicted mean 63.0
# true mean 69.56
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.31
# 2021-06-20 00:00:00 MAE: 10.01
# predicted mean 49.72
# true mean 57.86
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.23
# 2021-06-21 00:00:00 MAE: 18.44
# predicted mean 59.76
# true mean 78.19
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.31
# 2021-06-22 00:00:00 MAE: 15.59
# predicted mean 69.11
# true mean 84.7
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.2
# 2021-06-23 00:00:00 MAE: 11.25
# predicted mean 86.83
# true mean 93.47
# Terminated epoch 11/50 early: train loss: 0.03, val loss: 0.13
# 2021-06-24 00:00:00 MAE: 15.63
# predicted mean 79.37
# true mean 95.0
# Terminated epoch 26/50 early: train loss: 0.04, val loss: 0.15
# 2021-06-25 00:00:00 MAE: 16.46
# predicted mean 73.65
# true mean 90.1
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.17
# 2021-06-26 00:00:00 MAE: 9.69
# predicted mean 69.37
# true mean 78.82
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.15
# 2021-06-27 00:00:00 MAE: 14.72
# predicted mean 65.57
# true mean 65.23
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.19
# 2021-06-28 00:00:00 MAE: 13.59
# predicted mean 76.15
# true mean 88.85
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.17
# 2021-06-29 00:00:00 MAE: 13.97
# predicted mean 77.81
# true mean 91.75
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.14
# 2021-06-30 00:00:00 MAE: 13.3
# predicted mean 79.7
# true mean 92.28
# Terminated epoch 26/50 early: train loss: 0.03, val loss: 0.14
# 2021-07-01 00:00:00 MAE: 11.0
# predicted mean 86.11
# true mean 89.71
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.15
# 2021-07-02 00:00:00 MAE: 14.61
# predicted mean 88.62
# true mean 96.62
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.16
# 2021-07-03 00:00:00 MAE: 9.44
# predicted mean 81.86
# true mean 83.77
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.14
# 2021-07-04 00:00:00 MAE: 6.91
# predicted mean 83.16
# true mean 81.96
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.09
# 2021-07-05 00:00:00 MAE: 9.76
# predicted mean 84.88
# true mean 94.18
# Terminated epoch 31/50 early: train loss: 0.05, val loss: 0.05
# 2021-07-06 00:00:00 MAE: 10.83
# predicted mean 83.45
# true mean 79.22
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.06
# 2021-07-07 00:00:00 MAE: 6.31
# predicted mean 100.99
# true mean 96.48
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.12
# 2021-07-08 00:00:00 MAE: 36.83
# predicted mean 145.61
# true mean 108.78
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.07
# 2021-07-09 00:00:00 MAE: 9.83
# predicted mean 100.27
# true mean 91.4
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.07
# 2021-07-10 00:00:00 MAE: 14.63
# predicted mean 95.03
# true mean 80.49
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.12
# 2021-07-11 00:00:00 MAE: 18.27
# predicted mean 95.72
# true mean 77.45
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.1
# 2021-07-12 00:00:00 MAE: 3.99
# predicted mean 93.15
# true mean 93.98
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.12
# 2021-07-13 00:00:00 MAE: 13.41
# predicted mean 106.65
# true mean 94.23
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.1
# 2021-07-14 00:00:00 MAE: 17.97
# predicted mean 105.42
# true mean 87.46
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.14
# 2021-07-15 00:00:00 MAE: 10.59
# predicted mean 100.29
# true mean 89.71
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.09
# 2021-07-16 00:00:00 MAE: 12.24
# predicted mean 95.91
# true mean 83.67
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.06
# 2021-07-17 00:00:00 MAE: 12.82
# predicted mean 66.81
# true mean 54.44
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.18
# 2021-07-18 00:00:00 MAE: 27.98
# predicted mean 67.32
# true mean 39.34
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.51
# 2021-07-19 00:00:00 MAE: 6.75
# predicted mean 86.77
# true mean 88.98
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.5
# 2021-07-20 00:00:00 MAE: 18.0
# predicted mean 86.52
# true mean 73.59
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.37
# 2021-07-21 00:00:00 MAE: 7.26
# predicted mean 84.06
# true mean 89.99
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.61
# 2021-07-22 00:00:00 MAE: 4.07
# predicted mean 91.53
# true mean 87.63
# Terminated epoch 11/50 early: train loss: 0.03, val loss: 0.39
# 2021-07-23 00:00:00 MAE: 10.09
# predicted mean 98.86
# true mean 88.77
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.48
# 2021-07-24 00:00:00 MAE: 7.91
# predicted mean 74.4
# true mean 73.12
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.26
# 2021-07-25 00:00:00 MAE: 10.05
# predicted mean 71.35
# true mean 62.15
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.13
# 2021-07-26 00:00:00 MAE: 10.3
# predicted mean 78.51
# true mean 88.81
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.12
# 2021-07-27 00:00:00 MAE: 8.99
# predicted mean 80.25
# true mean 87.33
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.15
# 2021-07-28 00:00:00 MAE: 10.92
# predicted mean 68.31
# true mean 77.24
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.07
# 2021-07-29 00:00:00 MAE: 22.97
# predicted mean 60.43
# true mean 38.71
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.37
# 2021-07-30 00:00:00 MAE: 13.02
# predicted mean 70.39
# true mean 58.94
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.52
# 2021-07-31 00:00:00 MAE: 14.02
# predicted mean 52.88
# true mean 39.42
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.39
# 2021-08-01 00:00:00 MAE: 12.96
# predicted mean 58.71
# true mean 57.18
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.48
# 2021-08-02 00:00:00 MAE: 12.52
# predicted mean 94.34
# true mean 82.03
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.6
# 2021-08-03 00:00:00 MAE: 20.38
# predicted mean 76.23
# true mean 96.61
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.39
# 2021-08-04 00:00:00 MAE: 4.75
# predicted mean 94.11
# true mean 98.18
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.6
# 2021-08-05 00:00:00 MAE: 17.49
# predicted mean 75.98
# true mean 92.93
# Terminated epoch 16/50 early: train loss: 0.03, val loss: 0.16
# 2021-08-06 00:00:00 MAE: 8.77
# predicted mean 62.98
# true mean 69.69
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.31
# 2021-08-07 00:00:00 MAE: 9.66
# predicted mean 56.87
# true mean 57.09
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.24
# 2021-08-08 00:00:00 MAE: 14.5
# predicted mean 22.31
# true mean 18.16
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.35
# 2021-08-09 00:00:00 MAE: 6.43
# predicted mean 72.03
# true mean 71.26
# Terminated epoch 21/50 early: train loss: 0.04, val loss: 0.61
# 2021-08-10 00:00:00 MAE: 24.19
# predicted mean 67.89
# true mean 92.08
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.41
# 2021-08-11 00:00:00 MAE: 24.31
# predicted mean 76.96
# true mean 101.27
# Terminated epoch 11/50 early: train loss: 0.03, val loss: 0.5
# 2021-08-12 00:00:00 MAE: 35.05
# predicted mean 71.15
# true mean 106.2
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.28
# 2021-08-13 00:00:00 MAE: 7.24
# predicted mean 90.38
# true mean 93.8
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.26
# 2021-08-14 00:00:00 MAE: 11.06
# predicted mean 56.36
# true mean 61.44
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.25
# 2021-08-15 00:00:00 MAE: 8.83
# predicted mean 57.8
# true mean 61.51
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.32
# 2021-08-16 00:00:00 MAE: 10.86
# predicted mean 63.47
# true mean 72.42
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.26
# 2021-08-17 00:00:00 MAE: 10.85
# predicted mean 57.11
# true mean 65.34
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.26
# 2021-08-18 00:00:00 MAE: 21.32
# predicted mean 52.39
# true mean 73.71
# Terminated epoch 21/50 early: train loss: 0.04, val loss: 0.61
# 2021-08-19 00:00:00 MAE: 24.92
# predicted mean 68.56
# true mean 93.48
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.47
# 2021-08-20 00:00:00 MAE: 6.26
# predicted mean 106.38
# true mean 102.87
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.55
# 2021-08-21 00:00:00 MAE: 7.28
# predicted mean 94.94
# true mean 90.05
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.25
# 2021-08-22 00:00:00 MAE: 5.04
# predicted mean 77.62
# true mean 77.57
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.27
# 2021-08-23 00:00:00 MAE: 12.76
# predicted mean 81.42
# true mean 94.19
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.27
# 2021-08-24 00:00:00 MAE: 6.76
# predicted mean 100.78
# true mean 96.22
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.2
# 2021-08-25 00:00:00 MAE: 5.0
# predicted mean 76.74
# true mean 80.44
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.13
# 2021-08-26 00:00:00 MAE: 6.38
# predicted mean 92.07
# true mean 89.71
# Terminated epoch 16/50 early: train loss: 0.06, val loss: 0.32
# 2021-08-27 00:00:00 MAE: 5.53
# predicted mean 90.67
# true mean 92.2
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.11
# 2021-08-28 00:00:00 MAE: 6.79
# predicted mean 90.14
# true mean 83.64
# Terminated epoch 21/50 early: train loss: 0.04, val loss: 0.07
# 2021-08-29 00:00:00 MAE: 11.97
# predicted mean 69.04
# true mean 81.01
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.06
# 2021-08-30 00:00:00 MAE: 11.28
# predicted mean 96.42
# true mean 107.69
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.08
# 2021-08-31 00:00:00 MAE: 7.11
# predicted mean 106.53
# true mean 110.17
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.04
# 2021-09-01 00:00:00 MAE: 19.09
# predicted mean 130.33
# true mean 112.17
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.05
# 2021-09-02 00:00:00 MAE: 11.64
# predicted mean 122.0
# true mean 117.39
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.2
# 2021-09-03 00:00:00 MAE: 22.38
# predicted mean 131.99
# true mean 111.4
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.07
# 2021-09-04 00:00:00 MAE: 21.08
# predicted mean 85.34
# true mean 106.42
# Terminated epoch 16/50 early: train loss: 0.03, val loss: 0.09
# 2021-09-05 00:00:00 MAE: 14.67
# predicted mean 85.28
# true mean 97.67
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.05
# 2021-09-06 00:00:00 MAE: 14.17
# predicted mean 116.23
# true mean 128.35
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.07
# 2021-09-07 00:00:00 MAE: 13.7
# predicted mean 114.38
# true mean 128.08
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.07
# 2021-09-08 00:00:00 MAE: 9.7
# predicted mean 126.99
# true mean 124.38
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.1
# 2021-09-09 00:00:00 MAE: 23.73
# predicted mean 107.26
# true mean 130.98
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.1
# 2021-09-10 00:00:00 MAE: 39.47
# predicted mean 100.34
# true mean 139.81
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.11
# 2021-09-11 00:00:00 MAE: 26.43
# predicted mean 99.85
# true mean 126.28
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.05
# 2021-09-12 00:00:00 MAE: 15.69
# predicted mean 104.43
# true mean 105.22
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.05
# 2021-09-13 00:00:00 MAE: 8.97
# predicted mean 135.19
# true mean 142.25
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.27
# 2021-09-14 00:00:00 MAE: 39.88
# predicted mean 104.39
# true mean 144.27
# Terminated epoch 11/50 early: train loss: 0.03, val loss: 0.17
# 2021-09-15 00:00:00 MAE: 60.12
# predicted mean 107.77
# true mean 167.89
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.16
# 2021-09-16 00:00:00 MAE: 37.46
# predicted mean 119.61
# true mean 157.07
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.12
# 2021-09-17 00:00:00 MAE: 23.85
# predicted mean 125.2
# true mean 147.26
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.07
# 2021-09-18 00:00:00 MAE: 9.78
# predicted mean 123.78
# true mean 128.15
# Terminated epoch 11/50 early: train loss: 0.03, val loss: 0.04
# 2021-09-19 00:00:00 MAE: 7.96
# predicted mean 92.44
# true mean 95.61
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.08
# 2021-09-20 00:00:00 MAE: 27.37
# predicted mean 125.84
# true mean 153.21
# Terminated epoch 21/50 early: train loss: 0.04, val loss: 0.05
# 2021-09-21 00:00:00 MAE: 20.61
# predicted mean 127.14
# true mean 147.73
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.04
# 2021-09-22 00:00:00 MAE: 16.19
# predicted mean 133.94
# true mean 135.22
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.04
# 2021-09-23 00:00:00 MAE: 21.56
# predicted mean 81.04
# true mean 66.23
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.26
# 2021-09-24 00:00:00 MAE: 15.65
# predicted mean 83.7
# true mean 96.23
# Terminated epoch 11/50 early: train loss: 0.03, val loss: 0.27
# 2021-09-25 00:00:00 MAE: 18.13
# predicted mean 112.73
# true mean 128.48
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.27
# 2021-09-26 00:00:00 MAE: 16.68
# predicted mean 110.47
# true mean 118.86
# Terminated epoch 11/50 early: train loss: 0.03, val loss: 0.29
# 2021-09-27 00:00:00 MAE: 24.39
# predicted mean 133.61
# true mean 127.29
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.35
# 2021-09-28 00:00:00 MAE: 12.36
# predicted mean 163.84
# true mean 156.18
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.31
# 2021-09-29 00:00:00 MAE: 22.45
# predicted mean 109.98
# true mean 124.3
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.38
# 2021-09-30 00:00:00 MAE: 21.56
# predicted mean 74.82
# true mean 95.03
# Terminated epoch 26/50 early: train loss: 0.04, val loss: 0.25
# 2021-10-01 00:00:00 MAE: 12.71
# predicted mean 72.59
# true mean 76.08
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.24
# 2021-10-02 00:00:00 MAE: 37.45
# predicted mean 76.49
# true mean 94.47
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.34
# 2021-10-03 00:00:00 MAE: 25.97
# predicted mean 33.15
# true mean 41.52
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.49
# 2021-10-04 00:00:00 MAE: 36.88
# predicted mean 110.55
# true mean 136.85
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.54
# 2021-10-05 00:00:00 MAE: 52.58
# predicted mean 107.45
# true mean 156.45
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.89
# 2021-10-06 00:00:00 MAE: 81.29
# predicted mean 127.23
# true mean 199.02
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.86
# 2021-10-07 00:00:00 MAE: 56.42
# predicted mean 239.83
# true mean 295.45
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.65
# 2021-10-08 00:00:00 MAE: 21.52
# predicted mean 179.77
# true mean 200.33
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.7
# 2021-10-09 00:00:00 MAE: 32.55
# predicted mean 155.66
# true mean 139.87
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.6
# 2021-10-10 00:00:00 MAE: 52.82
# predicted mean 84.72
# true mean 136.79
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.52
# 2021-10-11 00:00:00 MAE: 29.66
# predicted mean 136.32
# true mean 114.62
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.53
# 2021-10-12 00:00:00 MAE: 34.56
# predicted mean 154.57
# true mean 158.28
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.48
# 2021-10-13 00:00:00 MAE: 23.97
# predicted mean 169.98
# true mean 183.88
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.29
# 2021-10-14 00:00:00 MAE: 27.14
# predicted mean 134.9
# true mean 113.68
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.4
# 2021-10-15 00:00:00 MAE: 14.86
# predicted mean 78.78
# true mean 78.71
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.51
# 2021-10-16 00:00:00 MAE: 27.89
# predicted mean 73.56
# true mean 100.75
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.53
# 2021-10-17 00:00:00 MAE: 31.18
# predicted mean 139.6
# true mean 142.83
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.53
# 2021-10-18 00:00:00 MAE: 81.14
# predicted mean 261.76
# true mean 180.63
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.45
# 2021-10-19 00:00:00 MAE: 23.8
# predicted mean 154.52
# true mean 140.82
# Terminated epoch 11/50 early: train loss: 0.03, val loss: 0.45
# 2021-10-20 00:00:00 MAE: 24.24
# predicted mean 52.21
# true mean 59.29
# Terminated epoch 21/50 early: train loss: 0.04, val loss: 0.55
# 2021-10-21 00:00:00 MAE: 18.6
# predicted mean 60.68
# true mean 53.5
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.81
# 2021-10-22 00:00:00 MAE: 27.42
# predicted mean 42.96
# true mean 55.77
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.73
# 2021-10-23 00:00:00 MAE: 33.23
# predicted mean 102.4
# true mean 125.4
# Terminated epoch 11/50 early: train loss: 0.03, val loss: 0.56
# 2021-10-24 00:00:00 MAE: 10.01
# predicted mean 78.23
# true mean 83.97
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.58
# 2021-10-25 00:00:00 MAE: 23.86
# predicted mean 118.58
# true mean 107.91
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.63
# 2021-10-26 00:00:00 MAE: 53.59
# predicted mean 190.38
# true mean 136.79
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.6
# 2021-10-27 00:00:00 MAE: 57.05
# predicted mean 87.05
# true mean 30.0
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 1.35
# 2021-10-28 00:00:00 MAE: 24.75
# predicted mean 90.03
# true mean 65.44
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 1.3
# 2021-10-29 00:00:00 MAE: 8.99
# predicted mean 83.46
# true mean 80.46
# Terminated epoch 21/50 early: train loss: 0.04, val loss: 1.07
# 2021-10-30 00:00:00 MAE: 13.43
# predicted mean 67.02
# true mean 78.28
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 1.25
# 2021-10-31 00:00:00 MAE: 13.46
# predicted mean 65.13
# true mean 56.03
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 1.03
# 2021-11-01 00:00:00 MAE: 21.72
# predicted mean 49.74
# true mean 70.92
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 1.31
# 2021-11-02 00:00:00 MAE: 70.78
# predicted mean 126.58
# true mean 197.36
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 1.31
# 2021-11-03 00:00:00 MAE: 28.22
# predicted mean 174.28
# true mean 181.85
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 1.02
# 2021-11-04 00:00:00 MAE: 63.2
# predicted mean 100.34
# true mean 163.54
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 1.05
# 2021-11-05 00:00:00 MAE: 28.83
# predicted mean 61.12
# true mean 89.12
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 1.06
# 2021-11-06 00:00:00 MAE: 30.18
# predicted mean 44.46
# true mean 67.75
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 1.05
# 2021-11-07 00:00:00 MAE: 16.67
# predicted mean 39.99
# true mean 37.44
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 1.02
# 2021-11-08 00:00:00 MAE: 68.53
# predicted mean 111.2
# true mean 177.0
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 1.01
# 2021-11-09 00:00:00 MAE: 26.27
# predicted mean 85.77
# true mean 81.93
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.9
# 2021-11-10 00:00:00 MAE: 59.33
# predicted mean 105.6
# true mean 156.97
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.95
# 2021-11-11 00:00:00 MAE: 35.45
# predicted mean 149.65
# true mean 178.06
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.95
# 2021-11-12 00:00:00 MAE: 40.65
# predicted mean 110.43
# true mean 142.86
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.82
# 2021-11-13 00:00:00 MAE: 37.87
# predicted mean 129.48
# true mean 147.45
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.55
# 2021-11-14 00:00:00 MAE: 37.52
# predicted mean 104.54
# true mean 139.6
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.59
# 2021-11-15 00:00:00 MAE: 76.49
# predicted mean 147.11
# true mean 221.7
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.99
# 2021-11-16 00:00:00 MAE: 99.57
# predicted mean 132.8
# true mean 232.37
# Terminated epoch 26/50 early: train loss: 0.04, val loss: 0.4
# 2021-11-17 00:00:00 MAE: 25.81
# predicted mean 109.08
# true mean 91.88
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.47
# 2021-11-18 00:00:00 MAE: 14.47
# predicted mean 77.91
# true mean 82.14
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.4
# 2021-11-19 00:00:00 MAE: 22.13
# predicted mean 77.5
# true mean 58.94
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.62
# 2021-11-20 00:00:00 MAE: 17.81
# predicted mean 97.09
# true mean 85.63
# Terminated epoch 26/50 early: train loss: 0.04, val loss: 0.33
# 2021-11-21 00:00:00 MAE: 27.47
# predicted mean 118.21
# true mean 97.1
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.5
# 2021-11-22 00:00:00 MAE: 28.05
# predicted mean 162.53
# true mean 166.26
# Terminated epoch 6/50 early: train loss: 0.05, val loss: 0.44
# 2021-11-23 00:00:00 MAE: 36.74
# predicted mean 166.27
# true mean 137.89
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.57
# 2021-11-24 00:00:00 MAE: 91.8
# predicted mean 161.34
# true mean 199.0
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.83
# 2021-11-25 00:00:00 MAE: 31.59
# predicted mean 150.42
# true mean 125.13
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.64
# 2021-11-26 00:00:00 MAE: 24.74
# predicted mean 176.98
# true mean 165.28
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.4
# 2021-11-27 00:00:00 MAE: 41.9
# predicted mean 211.58
# true mean 177.88
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.53
# 2021-11-28 00:00:00 MAE: 89.0
# predicted mean 255.29
# true mean 197.07
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.4
# 2021-11-29 00:00:00 MAE: 71.65
# predicted mean 325.13
# true mean 263.46
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.39
# 2021-11-30 00:00:00 MAE: 42.76
# predicted mean 123.41
# true mean 124.4
# Terminated epoch 21/50 early: train loss: 0.05, val loss: 0.71
# 2021-12-01 00:00:00 MAE: 40.09
# predicted mean 110.61
# true mean 87.24
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.61
# 2021-12-02 00:00:00 MAE: 67.76
# predicted mean 176.38
# true mean 180.04
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.56
# 2021-12-03 00:00:00 MAE: 52.73
# predicted mean 188.25
# true mean 148.77
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.75
# 2021-12-04 00:00:00 MAE: 111.42
# predicted mean 269.78
# true mean 184.83
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.74
# 2021-12-05 00:00:00 MAE: 80.29
# predicted mean 202.86
# true mean 122.57
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.6
# 2021-12-06 00:00:00 MAE: 98.88
# predicted mean 283.89
# true mean 232.69
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.7
# 2021-12-07 00:00:00 MAE: 62.06
# predicted mean 121.17
# true mean 173.87
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.4
# 2021-12-08 00:00:00 MAE: 37.35
# predicted mean 138.41
# true mean 131.97
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.51
# 2021-12-09 00:00:00 MAE: 111.23
# predicted mean 346.26
# true mean 257.84
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.73
# 2021-12-10 00:00:00 MAE: 309.86
# predicted mean 540.71
# true mean 236.75
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.31
# 2021-12-11 00:00:00 MAE: 41.89
# predicted mean 243.28
# true mean 227.2
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.84
# 2021-12-12 00:00:00 MAE: 75.24
# predicted mean 251.65
# true mean 180.31
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.23
# 2021-12-13 00:00:00 MAE: 36.84
# predicted mean 198.87
# true mean 221.42
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.3
# 2021-12-14 00:00:00 MAE: 50.83
# predicted mean 236.29
# true mean 231.91
# Terminated epoch 26/50 early: train loss: 0.05, val loss: 0.33
# 2021-12-15 00:00:00 MAE: 22.28
# predicted mean 134.8
# true mean 120.85
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.36
# 2021-12-16 00:00:00 MAE: 43.67
# predicted mean 188.69
# true mean 171.32
# Terminated epoch 21/50 early: train loss: 0.05, val loss: 0.26
# 2021-12-17 00:00:00 MAE: 147.33
# predicted mean 344.12
# true mean 214.36
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.39
# 2021-12-18 00:00:00 MAE: 37.98
# predicted mean 104.31
# true mean 129.94
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.36
# 2021-12-19 00:00:00 MAE: 38.68
# predicted mean 87.4
# true mean 100.92
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.55
# 2021-12-20 00:00:00 MAE: 90.91
# predicted mean 281.36
# true mean 333.22
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.58
# 2021-12-21 00:00:00 MAE: 80.15
# predicted mean 429.37
# true mean 432.43
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.49
# 2021-12-22 00:00:00 MAE: 97.61
# predicted mean 302.02
# true mean 399.63
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.52
# 2021-12-23 00:00:00 MAE: 114.22
# predicted mean 187.85
# true mean 269.44
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.72
# 2021-12-24 00:00:00 MAE: 45.17
# predicted mean 149.09
# true mean 185.45
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.65
# 2021-12-25 00:00:00 MAE: 34.93
# predicted mean 217.54
# true mean 196.81
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.45
# 2021-12-26 00:00:00 MAE: 20.03
# predicted mean 173.19
# true mean 168.89
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.24
# 2021-12-27 00:00:00 MAE: 37.21
# predicted mean 116.19
# true mean 147.94
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.44
# 2021-12-28 00:00:00 MAE: 18.4
# predicted mean 129.22
# true mean 111.36
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.46
# 2021-12-29 00:00:00 MAE: 23.75
# predicted mean 144.37
# true mean 153.98
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.49
# 2021-12-30 00:00:00 MAE: 20.86
# predicted mean 68.08
# true mean 68.19
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.65
# 2021-12-31 00:00:00 MAE: 33.1
# predicted mean 76.03
# true mean 44.46
# Terminated epoch 21/50 early: train loss: 0.05, val loss: 0.78
# 2022-01-01 00:00:00 MAE: 28.27
# predicted mean 92.98
# true mean 82.7
# Terminated epoch 21/50 early: train loss: 0.05, val loss: 1.12
# 2022-01-02 00:00:00 MAE: 25.16
# predicted mean 78.15
# true mean 53.86
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 1.29
# 2022-01-03 00:00:00 MAE: 24.1
# ...
# predicted mean 902.88
# true mean 567.02
# Terminated epoch 6/50 early: train loss: 0.05, val loss: 0.34
# 2022-09-02 00:00:00 MAE: 357.08
# predicted mean 765.86
# true mean 408.78
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.54
# 2022-09-03 00:00:00 MAE: 101.05
# predicted mean 368.49
# true mean 285.25
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.82
# 2022-09-04 00:00:00 MAE: 91.56
# predicted mean 294.73
# true mean 245.8
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.76
# 2022-09-05 00:00:00 MAE: 108.95
# predicted mean 363.92
# true mean 359.51
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.8
# 2022-09-06 00:00:00 MAE: 92.31
# predicted mean 360.52
# true mean 420.88
# Terminated epoch 11/50 early: train loss: 0.07, val loss: 0.62
# 2022-09-07 00:00:00 MAE: 51.64
# predicted mean 411.52
# true mean 459.48
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.69
# 2022-09-08 00:00:00 MAE: 52.1
# predicted mean 466.12
# true mean 419.2
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.74
# 2022-09-09 00:00:00 MAE: 74.37
# predicted mean 346.58
# true mean 354.94
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.68
# 2022-09-10 00:00:00 MAE: 41.75
# predicted mean 378.3
# true mean 406.26
# Terminated epoch 21/50 early: train loss: 0.04, val loss: 0.39
# 2022-09-11 00:00:00 MAE: 21.47
# predicted mean 386.49
# true mean 387.16
# Terminated epoch 26/50 early: train loss: 0.05, val loss: 0.25
# 2022-09-12 00:00:00 MAE: 55.3
# predicted mean 436.73
# true mean 399.13
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.17
# 2022-09-13 00:00:00 MAE: 37.16
# predicted mean 340.4
# true mean 376.38
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.19
# 2022-09-14 00:00:00 MAE: 83.3
# predicted mean 346.51
# true mean 429.45
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.23
# 2022-09-15 00:00:00 MAE: 70.52
# predicted mean 283.63
# true mean 339.79
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.4
# 2022-09-16 00:00:00 MAE: 90.56
# predicted mean 215.68
# true mean 193.97
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.48
# 2022-09-17 00:00:00 MAE: 146.69
# predicted mean 210.49
# true mean 63.8
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.95
# 2022-09-18 00:00:00 MAE: 47.19
# predicted mean 124.62
# true mean 83.74
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.93
# 2022-09-19 00:00:00 MAE: 94.69
# predicted mean 196.22
# true mean 275.89
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 1.14
# 2022-09-20 00:00:00 MAE: 58.94
# predicted mean 308.15
# true mean 367.09
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.92
# 2022-09-21 00:00:00 MAE: 43.01
# predicted mean 345.45
# true mean 384.22
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.79
# 2022-09-22 00:00:00 MAE: 41.57
# predicted mean 360.33
# true mean 386.24
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.78
# 2022-09-23 00:00:00 MAE: 28.23
# predicted mean 397.64
# true mean 370.38
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.8
# 2022-09-24 00:00:00 MAE: 185.28
# predicted mean 527.09
# true mean 341.81
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.32
# 2022-09-25 00:00:00 MAE: 57.7
# predicted mean 327.47
# true mean 273.59
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.26
# 2022-09-26 00:00:00 MAE: 60.1
# predicted mean 222.83
# true mean 243.53
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.17
# 2022-09-27 00:00:00 MAE: 77.25
# predicted mean 253.99
# true mean 319.0
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.43
# 2022-09-28 00:00:00 MAE: 47.26
# predicted mean 426.91
# true mean 390.61
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.34
# 2022-09-29 00:00:00 MAE: 31.43
# predicted mean 407.79
# true mean 405.54
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.25
# 2022-09-30 00:00:00 MAE: 62.18
# predicted mean 299.23
# true mean 290.87
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.27
# 2022-10-01 00:00:00 MAE: 58.34
# predicted mean 141.2
# true mean 82.86
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.46
# 2022-10-02 00:00:00 MAE: 42.63
# predicted mean 100.0
# true mean 116.71
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.46
# 2022-10-03 00:00:00 MAE: 78.77
# predicted mean 202.9
# true mean 218.48
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.46
# 2022-10-04 00:00:00 MAE: 38.06
# predicted mean 204.19
# true mean 206.6
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.42
# 2022-10-05 00:00:00 MAE: 52.86
# predicted mean 96.34
# true mean 43.61
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.4
# 2022-10-06 00:00:00 MAE: 34.81
# predicted mean 57.07
# true mean 22.26
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.48
# 2022-10-07 00:00:00 MAE: 46.82
# predicted mean 76.93
# true mean 30.11
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.28
# 2022-10-08 00:00:00 MAE: 32.99
# predicted mean 83.43
# true mean 52.71
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.26
# 2022-10-09 00:00:00 MAE: 57.62
# predicted mean 166.24
# true mean 115.84
# Terminated epoch 26/50 early: train loss: 0.04, val loss: 0.35
# 2022-10-10 00:00:00 MAE: 34.97
# predicted mean 132.98
# true mean 155.62
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.34
# 2022-10-11 00:00:00 MAE: 37.81
# predicted mean 237.3
# true mean 250.6
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.2
# 2022-10-12 00:00:00 MAE: 40.0
# predicted mean 254.5
# true mean 280.36
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.32
# 2022-10-13 00:00:00 MAE: 51.65
# predicted mean 280.79
# true mean 258.38
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.25
# 2022-10-14 00:00:00 MAE: 57.72
# predicted mean 288.42
# true mean 257.1
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.28
# 2022-10-15 00:00:00 MAE: 15.52
# predicted mean 142.69
# true mean 146.56
# Terminated epoch 6/50 early: train loss: 0.05, val loss: 0.34
# 2022-10-16 00:00:00 MAE: 47.95
# predicted mean 145.63
# true mean 97.68
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.28
# 2022-10-17 00:00:00 MAE: 27.82
# predicted mean 154.94
# true mean 151.54
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.25
# 2022-10-18 00:00:00 MAE: 15.63
# predicted mean 172.62
# true mean 166.22
# Terminated epoch 6/50 early: train loss: 0.05, val loss: 0.14
# 2022-10-19 00:00:00 MAE: 22.22
# predicted mean 189.43
# true mean 167.85
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.15
# 2022-10-20 00:00:00 MAE: 21.99
# predicted mean 131.98
# true mean 138.77
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.1
# 2022-10-21 00:00:00 MAE: 49.3
# predicted mean 213.72
# true mean 164.52
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.13
# 2022-10-22 00:00:00 MAE: 27.96
# predicted mean 164.04
# true mean 137.11
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.15
# 2022-10-23 00:00:00 MAE: 42.07
# predicted mean 133.35
# true mean 91.28
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.18
# 2022-10-24 00:00:00 MAE: 49.11
# predicted mean 128.05
# true mean 78.95
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.2
# 2022-10-25 00:00:00 MAE: 22.29
# predicted mean 128.63
# true mean 107.95
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.2
# 2022-10-26 00:00:00 MAE: 32.27
# predicted mean 151.74
# true mean 121.02
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.2
# 2022-10-27 00:00:00 MAE: 37.33
# predicted mean 160.65
# true mean 123.32
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.31
# 2022-10-28 00:00:00 MAE: 47.0
# predicted mean 151.7
# true mean 104.7
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.19
# 2022-10-29 00:00:00 MAE: 45.07
# predicted mean 146.59
# true mean 101.52
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.1
# 2022-10-30 00:00:00 MAE: 46.69
# predicted mean 165.01
# true mean 118.31
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.18
# 2022-10-31 00:00:00 MAE: 29.36
# predicted mean 172.55
# true mean 143.19
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.15
# 2022-11-01 00:00:00 MAE: 66.23
# predicted mean 133.9
# true mean 67.67
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.19
# 2022-11-02 00:00:00 MAE: 18.73
# predicted mean 76.0
# true mean 70.36
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.15
# 2022-11-03 00:00:00 MAE: 13.65
# predicted mean 77.72
# true mean 83.81
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.14
# 2022-11-04 00:00:00 MAE: 50.44
# predicted mean 136.31
# true mean 103.89
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.17
# 2022-11-05 00:00:00 MAE: 46.9
# predicted mean 121.76
# true mean 85.65
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.21
# 2022-11-06 00:00:00 MAE: 41.24
# predicted mean 75.6
# true mean 34.36
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.13
# 2022-11-07 00:00:00 MAE: 35.96
# predicted mean 88.19
# true mean 55.21
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.11
# 2022-11-08 00:00:00 MAE: 41.02
# predicted mean 93.58
# true mean 52.56
# Terminated epoch 6/50 early: train loss: 0.05, val loss: 0.18
# 2022-11-09 00:00:00 MAE: 57.09
# predicted mean 139.11
# true mean 82.85
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.13
# 2022-11-10 00:00:00 MAE: 67.21
# predicted mean 120.55
# true mean 61.69
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.14
# 2022-11-11 00:00:00 MAE: 48.84
# predicted mean 50.79
# true mean 1.95
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.14
# 2022-11-12 00:00:00 MAE: 28.01
# predicted mean 161.09
# true mean 148.26
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.13
# 2022-11-13 00:00:00 MAE: 19.96
# predicted mean 122.36
# true mean 141.65
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.14
# 2022-11-14 00:00:00 MAE: 42.7
# predicted mean 120.06
# true mean 150.39
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.2
# 2022-11-15 00:00:00 MAE: 57.23
# predicted mean 122.83
# true mean 71.53
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.22
# 2022-11-16 00:00:00 MAE: 66.79
# predicted mean 94.18
# true mean 27.39
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.21
# 2022-11-17 00:00:00 MAE: 49.37
# predicted mean 36.86
# true mean 48.71
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.18
# 2022-11-18 00:00:00 MAE: 41.5
# predicted mean 86.98
# true mean 111.89
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.26
# 2022-11-19 00:00:00 MAE: 56.98
# predicted mean 140.04
# true mean 194.91
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.27
# 2022-11-20 00:00:00 MAE: 20.82
# predicted mean 190.7
# true mean 207.19
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.28
# 2022-11-21 00:00:00 MAE: 51.32
# predicted mean 218.56
# true mean 252.75
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.27
# 2022-11-22 00:00:00 MAE: 59.4
# predicted mean 113.58
# true mean 170.97
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.33
# 2022-11-23 00:00:00 MAE: 20.92
# predicted mean 131.59
# true mean 150.25
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.39
# 2022-11-24 00:00:00 MAE: 30.86
# predicted mean 208.45
# true mean 239.05
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.33
# 2022-11-25 00:00:00 MAE: 23.4
# predicted mean 266.29
# true mean 257.99
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.51
# 2022-11-26 00:00:00 MAE: 18.45
# predicted mean 238.61
# true mean 235.81
# Terminated epoch 11/50 early: train loss: 0.06, val loss: 0.26
# 2022-11-27 00:00:00 MAE: 17.01
# predicted mean 135.45
# true mean 140.34
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.27
# 2022-11-28 00:00:00 MAE: 54.15
# predicted mean 228.5
# true mean 193.39
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.31
# 2022-11-29 00:00:00 MAE: 45.76
# predicted mean 329.84
# true mean 363.58
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.28
# 2022-11-30 00:00:00 MAE: 144.44
# predicted mean 538.29
# true mean 393.85
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.25
# 2022-12-01 00:00:00 MAE: 80.14
# predicted mean 440.7
# true mean 394.95
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.32
# 2022-12-02 00:00:00 MAE: 88.91
# predicted mean 327.91
# true mean 330.16
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.56
# 2022-12-03 00:00:00 MAE: 96.76
# predicted mean 165.2
# true mean 261.95
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.26
# 2022-12-04 00:00:00 MAE: 88.36
# predicted mean 317.96
# true mean 262.6
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.29
# 2022-12-05 00:00:00 MAE: 162.17
# predicted mean 441.11
# true mean 311.06
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.36
# 2022-12-06 00:00:00 MAE: 47.05
# predicted mean 365.24
# true mean 385.05
# Terminated epoch 21/50 early: train loss: 0.04, val loss: 0.65
# 2022-12-07 00:00:00 MAE: 66.66
# predicted mean 262.14
# true mean 325.74
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.33
# 2022-12-08 00:00:00 MAE: 68.02
# predicted mean 328.37
# true mean 389.11
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.22
# 2022-12-09 00:00:00 MAE: 111.51
# predicted mean 515.52
# true mean 410.04
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.15
# 2022-12-10 00:00:00 MAE: 138.47
# predicted mean 492.62
# true mean 354.15
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.09
# 2022-12-11 00:00:00 MAE: 76.08
# predicted mean 398.94
# true mean 325.91
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.11
# 2022-12-12 00:00:00 MAE: 78.01
# predicted mean 513.0
# true mean 435.0
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.07
# 2022-12-13 00:00:00 MAE: 52.75
# predicted mean 492.05
# true mean 442.95
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.09
# 2022-12-14 00:00:00 MAE: 32.26
# predicted mean 416.62
# true mean 444.9
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.06
# 2022-12-15 00:00:00 MAE: 68.17
# predicted mean 463.89
# true mean 396.81
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.22
# 2022-12-16 00:00:00 MAE: 121.82
# predicted mean 531.88
# true mean 410.05
# Terminated epoch 11/50 early: train loss: 0.04, val loss: 0.28
# 2022-12-17 00:00:00 MAE: 64.04
# predicted mean 302.23
# true mean 238.19
# Terminated epoch 16/50 early: train loss: 0.04, val loss: 0.12
# 2022-12-18 00:00:00 MAE: 36.05
# predicted mean 168.41
# true mean 187.42
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.17
# 2022-12-19 00:00:00 MAE: 84.92
# predicted mean 106.51
# true mean 191.43
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.35
# 2022-12-20 00:00:00 MAE: 33.3
# predicted mean 162.17
# true mean 188.9
# Terminated epoch 6/50 early: train loss: 0.06, val loss: 0.49
# 2022-12-21 00:00:00 MAE: 33.42
# predicted mean 245.91
# true mean 213.6
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.38
# 2022-12-22 00:00:00 MAE: 23.31
# predicted mean 169.99
# true mean 191.61
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.46
# 2022-12-23 00:00:00 MAE: 14.13
# predicted mean 187.71
# true mean 183.06
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.36
# 2022-12-24 00:00:00 MAE: 44.71
# predicted mean 157.47
# true mean 114.77
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.35
# 2022-12-25 00:00:00 MAE: 31.12
# predicted mean 134.21
# true mean 103.1
# Terminated epoch 16/50 early: train loss: 0.05, val loss: 0.22
# 2022-12-26 00:00:00 MAE: 42.76
# predicted mean 79.6
# true mean 39.86
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.16
# 2022-12-27 00:00:00 MAE: 37.67
# predicted mean 111.41
# true mean 92.44
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.21
# 2022-12-28 00:00:00 MAE: 43.25
# predicted mean 96.84
# true mean 56.18
# Terminated epoch 11/50 early: train loss: 0.05, val loss: 0.23
# 2022-12-29 00:00:00 MAE: 76.83
# predicted mean 90.92
# true mean 14.09
# Terminated epoch 6/50 early: train loss: 0.03, val loss: 0.17
# 2022-12-30 00:00:00 MAE: 26.19
# predicted mean -11.79
# true mean 14.16
# Terminated epoch 6/50 early: train loss: 0.04, val loss: 0.5
# 2022-12-31 00:00:00 MAE: 100.34
# predicted mean 102.36
# true mean 18.32

# %%
# save predictions
# concat predictions
predictions = pd.concat(predictions, axis=0)
predictions_path = os.path.join(os.getcwd(), 'predictions', f'DNN4_predictions_all.pkl')
pickle.dump(predictions, open(predictions_path, 'wb'))

# %%
# save actual values
actuals_path = os.path.join(os.getcwd(), 'predictions', f'DNN4_actuals_all.pkl')
pickle.dump(y_test, open(actuals_path, 'wb'))
